# %% [markdown]
# import mglearn
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.svm import LinearSVC
#
#
# x, y = make_blobs(random_state=42)
# mglearn.discrete_scatter(x[:,0], x[:,1], y)
# plt.xlabel("feature1")
# plt.ylabel("feature2")
# plt.legend(["class0","class1","class2"])
#
# #해당 데이터 셋으로 linearSVC 분류기를 훈련
# linear_svc = LinearSVC().fit(x,y)
# print("w size = ",linear_svc.coef_.shape)
# print("b size = ",linear_svc.intercept_.shape)
#
# #세 개의 이진 분류기가 만드는 경계를 시각화 해보자
# mglearn.discrete_scatter(x[:,0],x[:,1],y)
# line = np.linspace(-15,15)
# for coef, intercept, color in zip(linear_svm.coef_,linear_svm.intercept_,mglearn.cm3.colors):
#     plt.plot(line,-(line*coef[0]+intercept)/coef[1],c=color)
# plt.ylim(-10,15)
# plt.xlim(-10,8)
# plt.xlabel("feature0")
# plt.ylabel("feature1")
# plt.legend(['class0','class1','class2','class 0 b','class 1 b', 'cass 2 b'],loc =(1.01,0.3))

# %%
import mglearn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC


x, y = make_blobs(random_state=42)

mglearn.plots.plot_2d_classification(linear_svm, x, fill= True, alpha=.7)
mglearn.discrete_scatter(x[:,0],x[:,1],y)
line = np.linspace(-15,15)

for coef, intercept, color, in zip(linear_svc.coef_,linear_svm.intercept_,mglearn.cm3.colors):
    plt.plot(line,-(line * coef[0] + intercept)/coef[1], c = color)
plt.xlabel("feature0")
plt.ylabel("feature1")
plt.legend(['class0','class1','class2','class 0 b','class 1 b', 'cass 2 b'],loc =(1.01,0.3))

# %% [markdown]
# ## 선형 모델의 장단점
#
# ### 특징
# #### 1. 샘플에 비해 feature이 많을 때 잘 작동
# #### 2. 다른 모델로 학습하기 어려운 매우 큰 데이터셋에 선형모델을 사용
# ### 장점
# #### 1. 학습 속도가 빠름
# #### 2. 예측도 빠름
# #### 3. 매우 큰 데이터셋, 희소한 데이터셋 모두 잘 작동
# #### 4. 예측이 어떻게 만들어 지는지 비교적 쉽게 이해 가능
# tip 데이터셋이 클 때 logistic regression, ridge에서 sover = 'sag'옵션 주자
#
# ### 단점
# #### 1. 저차원 데이터셋에서는 다른 모델의 일반화 성능이 더 좋다.
